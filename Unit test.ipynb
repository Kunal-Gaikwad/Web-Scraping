# %% [markdown]
# In \[1\]:
#
#     import unittest
#     from app import app_beekin
#     import requests
#
#     C:\Users\Arturs\anaconda3\lib\site-packages\flask_limiter\extension.py:293: UserWarning: Using the in-memory storage for tracking rate limits as no storage was explicitly specified. This is not recommended for production use. See: https://flask-limiter.readthedocs.io#configuring-a-storage-backend for documentation about configuring the storage backend.
#       warnings.warn(
#
# In \[2\]:
#
#     import unittest
#     import json
#     from app import app_beekin
#
#     class TestAPI(unittest.TestCase):
#
#         def setUp(self):
#             self.app = app_beekin.test_client()
#
#         def test_fetch(self):
#             response = self.app.get('/jobresults?location=london&technology=java')
#             self.assertEqual(response.status_code, 200)
#             data = json.loads(response.data)
#             self.assertIsInstance(data, list)
#
#         def test_job_results_pagination(self):
#             result = self.app.get('/jobresults?location=london&technology=java&page=1&per_page=2')
#             self.assertEqual(result.status_code, 200)
#             self.assertEqual(len(result.json), 2)
#
#         def test_job_results_data(self):
#             result = self.app.get('/jobresults?location=london&technology=java')
#             self.assertIn(b'title', result.data)
#             self.assertIn(b'location', result.data)
#             self.assertIn(b'description', result.data)
#             self.assertIn(b'salary', result.data)
#             self.assertIn(b'date_posted', result.data)
#             self.assertIn(b'company', result.data)
#             self.assertIn(b'technology', result.data)
#
#     if __name__ == '__main__':
#         unittest.main(argv=['first-arg-is-ignored'], exit=False)
#
#     ...
#     ----------------------------------------------------------------------
#     Ran 3 tests in 0.168s
#
#     OK
#
# In \[ \]:
